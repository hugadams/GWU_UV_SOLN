# %%
# %run ../NBCONFIG.ipynb
# Out:
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
#
# div #notebook { /* centre the content */
#     background: #FFFFF0;  /* IVORY */
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
#
# div.text_cell_render {  /*Markdown cells */
#     font-family: Computer Modern Roman;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0; /*What is this */
#     padding: 0.05; /*Spacing between cells*/
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0.05;
# }
#
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# /* Width of all cells */
# div.cell { /* set cell width to about 80 chars */
#     width: 55em;
# ...

# %% [markdown]
# # Measuring USB650 Drift (5-30-12)

# %% [markdown]
# This was done prior to issues with USB lightsource, so the results are very stable.  **The first time point in data should be removed as it is dark spectrum, but doing this via gwuspec -p t_start was problemetic**.  This should work in gwuspec, so troubleshoot later if you need better plots.  Even at the full scale, it's clear that the stability was good.  Going to just copy a few plots.

# %% [markdown]
# #### 1 hour after warm

# %% [markdown]
# After allowing spectrometer to warmup for an hour, here is the drift for another three hours:

# %%
from IPython.core.display import Image 
Image(filename='1hr_after_warmup.png')

# %%
Image(filename='1hr_after_warmup_area.png')

# %% [markdown]
# #### A full day later, the stability was measured for approximately the same time (presumably leaving the spectrometer on the whole time):

# %%
Image(filename='full_day_after.png')

# %%
Image(filename='full_day_after_area.png')

# %% [markdown]
# **That is the stability we need to get to again! **
