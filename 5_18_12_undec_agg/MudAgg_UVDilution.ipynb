# %% [markdown]
# # UVVIs sizing and MUD test

# %%
# %run ../NBCONFIG.ipynb
# Out:
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
#
# div #notebook { /* centre the content */
#     background: #FFFFF0;  /* IVORY */
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
#
# div.text_cell_render {  /*Markdown cells */
#     font-family: Computer Modern Roman;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0; /*What is this */
#     padding: 0.05; /*Spacing between cells*/
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0.05;
# }
#
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# /* Width of all cells */
# div.cell { /* set cell width to about 80 chars */
#     width: 55em;
# ...

# %% [markdown]
# **These were first experiments done with the USB650 spectrometer.**
#
# Goals were to estimate size and concentration of UVVis spectra of nanoparticles using haiss.  As a corollary, observed MUD aggregations.   All that I really get out of this is yet another dilution measurement and mud aggregation.
#
# I will just import relevant plots:

# %% [markdown]
# #### Concentration data

# %%
from IPython.core.display import Image 
Image(filename='Absorbance_spectrum.png')

# %%
Image(filename='Absorbance_area.png')

# %% [markdown]
# #### MUD Aggregation

# %% [markdown]
# After AuNP was added as shown above, added 50uL drop of 1.9mM in ethanol MUD (cf=35.8uM) and stirred.  Mad aggregation (below shows raw and absobrance {log} change)

# %%
Image(filename='undec_abs.png')

# %%
Image(filename='undec_raw.png')
